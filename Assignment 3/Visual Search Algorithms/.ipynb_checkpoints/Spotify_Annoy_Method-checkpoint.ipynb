# %%
import tensorflow as tf
import tensorflow_hub as hub
# For saving 'feature vectors' into a txt file
import numpy as np
# Glob for reading file names in a folder
import glob
import os.path
from tqdm import tqdm
import ntpath
import warnings
import cv2
from annoy import AnnoyIndex
from scipy import spatial
warnings.filterwarnings('ignore')
from operator import itemgetter

# %%
def load_img(path):
    # Reads the image file and returns data type of string
    img = tf.io.read_file(path)
    # Decodes the image to W x H x 3 shape tensor with type of uint8
    img = tf.io.decode_jpeg(img, channels=3)
    # Resizes the image to 224 x 224 x 3 shape tensor
    img = tf.image.resize_with_pad(img, 224, 224)
    # Converts the data type of uint8 to float32 by adding a new axis
    # img becomes 1 x 224 x 224 x 3 tensor with data type of float32
    # This is required for the mobilenet model we are using
    img = tf.image.convert_image_dtype(img,tf.float32)[tf.newaxis, ...]

    return img

# %%
def match_id(filename):
    product_id = '_'.join(filename.split('_')[:-1])
    return product_id

# %%
image_paths= glob.glob('images/*.jpg')

# %%
def get_image_feature_vectors(path):
    module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4"
    # Loads the module
    module = hub.load(module_handle)
    # Loops through all images in a local folder

    #print(path)
    # Loads and pre-process the image
    img = load_img(path)
    # Calculate the image feature vector of the img
    features = module(img)
    # Remove single-dimensional entries from the 'features' array  
    feature_set = np.squeeze(features)

    # Saves the image feature vectors into a file for later use
    outfile_name = os.path.basename(filename) + ".npz"

    out_path = os.path.join('Images_Scraped/',outfile_name)
    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

# %%
def get_features(img, image_path): 
     # Definition of module with using tfhub.dev
    module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4"
    # Loads the module
    module = hub.load(module_handle)
    features = module(img)
    # Remove single-dimensional entries from the 'features' array  
    feature_set = np.squeeze(features)
    #print(image_path)

    # Saves the image feature vectors into a file for later use
    outfile_name = os.path.basename(image_path) + ".npz"

    out_path = os.path.join('images_scrapped/',outfile_name)
    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')
    vector = np.loadtxt(out_path)
    return vector

# %%
image_paths= glob.glob('images/*.jpg')
vectorfiles = glob.glob('images_scrapped/*.npz')
# compute styles
image_style_embeddings = {}

for image_path in tqdm(image_paths): 
    image_tensor = load_img(image_path)
    vector = get_features(image_tensor, image_path)
    image_style_embeddings[ntpath.basename(image_path)] = vector
# Out:
#   3%|▎         | 4/116 [00:24<11:53,  6.37s/it]
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E804E68168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E804E68168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   4%|▍         | 5/116 [00:29<11:16,  6.09s/it]
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038F11F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038F11F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   5%|▌         | 6/116 [00:36<11:17,  6.16s/it]
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803A5B288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803A5B288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   6%|▌         | 7/116 [00:41<10:50,  5.96s/it]
# WARNING:tensorflow:8 out of the last 8 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8025B94C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8025B94C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   7%|▋         | 8/116 [00:48<10:53,  6.05s/it]
# WARNING:tensorflow:9 out of the last 9 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87194EA68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87194EA68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   8%|▊         | 9/116 [00:53<10:18,  5.78s/it]
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8011C21F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8011C21F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   9%|▊         | 10/116 [00:59<10:17,  5.83s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803CC2E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803CC2E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   9%|▉         | 11/116 [01:05<10:24,  5.95s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8011E73A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8011E73A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  10%|█         | 12/116 [01:10<09:38,  5.57s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803CCB1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803CCB1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  11%|█         | 13/116 [01:15<09:40,  5.64s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A1E9048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A1E9048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  12%|█▏        | 14/116 [01:21<09:43,  5.72s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E871B16048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E871B16048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  13%|█▎        | 15/116 [01:26<09:20,  5.55s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E80125D1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E80125D1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  14%|█▍        | 16/116 [01:32<09:03,  5.44s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87DA56438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87DA56438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  15%|█▍        | 17/116 [01:38<09:13,  5.59s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803627438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803627438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  16%|█▌        | 18/116 [01:43<08:50,  5.42s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8010651F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8010651F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  16%|█▋        | 19/116 [01:48<08:34,  5.31s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E80105A438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E80105A438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  17%|█▋        | 20/116 [01:54<09:04,  5.67s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803BFD438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803BFD438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  18%|█▊        | 21/116 [01:59<08:36,  5.44s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87C5231F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87C5231F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  19%|█▉        | 22/116 [02:05<08:33,  5.46s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038AC288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038AC288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  20%|█▉        | 23/116 [02:11<08:43,  5.62s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E805128168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E805128168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  21%|██        | 24/116 [02:16<08:22,  5.46s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87C53D1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87C53D1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  22%|██▏       | 25/116 [02:21<08:21,  5.51s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803E1F288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803E1F288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  22%|██▏       | 26/116 [02:27<08:18,  5.54s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E804E27168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E804E27168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  23%|██▎       | 27/116 [02:32<08:06,  5.46s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87B3E01F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87B3E01F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  24%|██▍       | 28/116 [02:38<08:10,  5.58s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E802493288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E802493288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  25%|██▌       | 29/116 [02:44<08:11,  5.65s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038594C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038594C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  26%|██▌       | 30/116 [02:49<07:56,  5.54s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E871944A68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E871944A68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  27%|██▋       | 31/116 [02:55<08:11,  5.78s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038641F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8038641F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  28%|██▊       | 32/116 [03:00<07:45,  5.54s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E801297E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E801297E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  28%|██▊       | 33/116 [03:06<07:49,  5.65s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87D7F33A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87D7F33A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  29%|██▉       | 34/116 [03:12<07:53,  5.78s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8025A41F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
#  91%|█████████▏| 106/116 [09:54<00:58,  5.90s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8050911F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8050911F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  92%|█████████▏| 107/116 [09:59<00:49,  5.55s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87D88C438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87D88C438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  93%|█████████▎| 108/116 [10:04<00:44,  5.62s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87DB63438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87DB63438> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  94%|█████████▍| 109/116 [10:10<00:39,  5.67s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A2961F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A2961F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  95%|█████████▍| 110/116 [10:16<00:33,  5.54s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E802506288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E802506288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  96%|█████████▌| 111/116 [10:21<00:27,  5.42s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8050AA168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8050AA168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  97%|█████████▋| 112/116 [10:27<00:23,  5.79s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A2A0C18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E87A2A0C18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  97%|█████████▋| 113/116 [10:32<00:16,  5.61s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803928288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803928288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  98%|█████████▊| 114/116 [10:38<00:11,  5.53s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803B0C168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E803B0C168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  99%|█████████▉| 115/116 [10:44<00:05,  5.70s/it]
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8024F51F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x000001E8024F51F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100%|██████████| 116/116 [10:49<00:00,  5.60s/it]

# %%
def cluster():
    print("-------Annoy Index Generation----------------")
    # Defining data structures as empty dict
    file_index_to_file_name = {}
    file_index_to_file_vector = {}
    file_index_to_product_id = {}
    # Configuring annoy parameters
    dims = 1792
    n_nearest_neighbors = 20
    trees = 10000
    # Reads all file names which stores feature vectors
    allfiles = glob.glob(('images_scrapped/*.npz'))

    t = AnnoyIndex(dims, metric='angular')
    
    for file_index, i in enumerate(allfiles):
    # Reads feature vectors and assigns them into the file_vector 
        file_vector = np.loadtxt(i)

        # Assigns file_name, feature_vectors and corresponding product_id
        file_name = os.path.basename(i).split('.')[0]
        file_index_to_file_name[file_index] = file_name
        file_index_to_file_vector[file_index] = file_vector
        file_index_to_product_id[file_index] = match_id(file_name)

        # Adds image feature vectors into annoy index   
        t.add_item(file_index, file_vector)

        print("---------------------------------")
        print("Annoy index     : %s" %file_index)
        print("Image file name : %s" %file_name)
        print("Product id      : %s" %file_index_to_product_id[file_index])
        #print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


    # Builds annoy index
    t.build(trees)

    print ("Step.1 - ANNOY index generation - Finished")
    print ("Step.2 - Similarity score calculation - Started ") 
  
    global named_nearest_neighbors
    named_nearest_neighbors = []

  # Loops through all indexed items
    for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
        master_file_name = file_index_to_file_name[i]
        master_vector = file_index_to_file_vector[i]
        master_product_id = file_index_to_product_id[i]

        # Calculates the nearest neighbors of the master item
        nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

        # Loops through the nearest neighbors of the master item
        for j in nearest_neighbors:

            # Assigns file_name, image feature vectors and product id values of the similar item
            neighbor_file_name = file_index_to_file_name[j]
            neighbor_file_vector = file_index_to_file_vector[j]
            neighbor_product_id = file_index_to_product_id[j]

            # Calculates the similarity score of the similar item
            similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
            rounded_similarity = int((similarity * 10000)) / 10000.0

            # Appends master product id with the similarity score 
            # and the product id of the similar items
            named_nearest_neighbors.append({
            'similarity': rounded_similarity,
            'master_pi': master_product_id,
            'similar_pi': neighbor_product_id})
#     print(named_nearest_neighbors)
#     print(type(named_nearest_neighbors))
            
#     return named_nearest_neighbors

# %%
image_paths = glob.glob('images/*.jpg')
print(f'Founnd [{len(image_paths)}] images')

images = []
for image_path in image_paths:
    image = cv2.imread(image_path, 3)
    b,g,r = cv2.split(image)           # get b, g, r
    image = cv2.merge([r,g,b])         # switch it to r, g, b
    image = cv2.resize(image, (200, 200))
    product_id = match_id(ntpath.basename(image_path))
    images.append({
      'image_path' : ntpath.basename(image_path),
        'image' : image,
       'product_id':product_id
    })
#     images['image_path'] = ntpath.basename(image_path)
#     images['image'] = image
#     #images[ntpath.basename(image_path)] = image
#     product_id = match_id(ntpath.basename(image_path))
#     images['product_id'] = product_id
# Out:
# Founnd [116] images

# %%
cluster()
# Out:
# -------Annoy Index Generation----------------
# ---------------------------------
# Annoy index     : 0
# Image file name : 3592260_0
# Product id      : 3592260
# ---------------------------------
# Annoy index     : 1
# Image file name : 3600246_0
# Product id      : 3600246
# ---------------------------------
# Annoy index     : 2
# Image file name : 3606787_1
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 3
# Image file name : 3606787_2
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 4
# Image file name : 3606787_3
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 5
# Image file name : 3607594_0
# Product id      : 3607594
# ---------------------------------
# Annoy index     : 6
# Image file name : 3607977_0
# Product id      : 3607977
# ---------------------------------
# Annoy index     : 7
# Image file name : 3607977_1
# Product id      : 3607977
# ---------------------------------
# Annoy index     : 8
# Image file name : 3615116_0
# Product id      : 3615116
# ---------------------------------
# Annoy index     : 9
# Image file name : 3615116_1
# Product id      : 3615116
# ---------------------------------
# Annoy index     : 10
# Image file name : 3616121_0
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 11
# Image file name : 3616121_1
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 12
# Image file name : 3616121_2
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 13
# Image file name : 3616434_0
# Product id      : 3616434
# ---------------------------------
# Annoy index     : 14
# Image file name : 3616746_0
# Product id      : 3616746
# ---------------------------------
# Annoy index     : 15
# Image file name : 3626900_0
# Product id      : 3626900
# ---------------------------------
# Annoy index     : 16
# Image file name : 3627022_0
# Product id      : 3627022
# ---------------------------------
# Annoy index     : 17
# Image file name : 3627022_1
# Product id      : 3627022
# ---------------------------------
# Annoy index     : 18
# Image file name : 3627537_0
# Product id      : 3627537
# ---------------------------------
# Annoy index     : 19
# Image file name : 3632446_0
# Product id      : 3632446
# ---------------------------------
# Annoy index     : 20
# Image file name : 3638804_0
# Product id      : 3638804
# ---------------------------------
# Annoy index     : 21
# Image file name : 3641703_0
# Product id      : 3641703
# ---------------------------------
# Annoy index     : 22
# Image file name : 3641703_1
# Product id      : 3641703
# ---------------------------------
# Annoy index     : 23
# Image file name : 3644655_0
# Product id      : 3644655
# ---------------------------------
# Annoy index     : 24
# Image file name : 3650251_0
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 25
# Image file name : 3650251_1
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 26
# Image file name : 3650251_2
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 27
# Image file name : 3650251_3
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 28
# Image file name : 3650946_0
# Product id      : 3650946
# ---------------------------------
# Annoy index     : 29
# Image file name : 3651269_0
# Product id      : 3651269
# ---------------------------------
# Annoy index     : 30
# Image file name : 3652195_0
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 31
# Image file name : 3652195_1
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 32
# Image file name : 3652195_2
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 33
# Image file name : 3652195_3
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 34
# Image file name : 3657088_0
# Product id      : 3657088
# ---------------------------------
# Annoy index     : 35
# Image file name : 3657088_1
# Product id      : 3657088
# ---------------------------------
# Annoy index     : 36
# Image file name : 3657693_0
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 37
# Image file name : 3657693_1
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 38
# Image file name : 3657693_2
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 39
# Image file name : 3658475_0
# Product id      : 3658475
# ---------------------------------
# Annoy index     : 40
# Image file name : 3659954_0
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 41
# Image file name : 3659954_1
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 42
# Image file name : 3659954_2
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 43
# Image file name : 3659954_3
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 44
# Image file name : 3661414_0
# Product id      : 3661414
# ---------------------------------
# Annoy index     : 45
# Image file name : 3661414_1
# Product id      : 3661414
# ---------------------------------
# Annoy index     : 46
# Image file name : 3669338_0
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 47
# Image file name : 3669338_1
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 48
# Image file name : 3669338_2
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 49
# Image file name : 3669338_3
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 50
# Image file name : 3672632_0
# Product id      : 3672632
# ---------------------------------
# Annoy index     : 51
# Image file name : 3673600_0
# Product id      : 3673600
# ---------------------------------
# Annoy index     : 52
# Image file name : 3673600_1
# Product id      : 3673600
# ---------------------------------
# Annoy index     : 53
# Image file name : 3673616_0
# Product id      : 3673616
# ---------------------------------
# Annoy index     : 54
# Image file name : 3674036_0
# Product id      : 3674036
# ---------------------------------
# Annoy index     : 55
# Image file name : 3676447_0
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 56
# Image file name : 3676447_1
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 57
# Image file name : 3676447_2
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 58
# Image file name : 3676447_3
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 59
# Image file name : 3678695_0
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 60
# Image file name : 3678695_1
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 61
# Image file name : 3678695_2
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 62
# Image file name : 3678695_3
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 63
# Image file name : 3681709_0
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 64
# Image file name : 3681709_1
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 65
# Image file name : 3681709_2
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 66
# Image file name : 3681709_3
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 67
# Image file name : 3683369_0
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 68
# Image file name : 3683369_1
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 69
# Image file name : 3683369_2
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 70
# Image file name : 3683369_3
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 71
# Image file name : 3683720_0
# Product id      : 3683720
# ---------------------------------
# Annoy index     : 72
# Image file name : 3683720_1
# Product id      : 3683720
# ---------------------------------
# Annoy index     : 73
# Image file name : 3689141_0
# Product id      : 3689141
# ---------------------------------
# Annoy index     : 74
# Image file name : 3689141_1
# Product id      : 3689141
# ---------------------------------
# Annoy index     : 75
# Image file name : 3689266_0
# Product id      : 3689266
# ---------------------------------
# Annoy index     : 76
# Image file name : 3690110_0
# Product id      : 3690110
# ---------------------------------
# Annoy index     : 77
# Image file name : 3691506_0
# Product id      : 3691506
# ---------------------------------
# Annoy index     : 78
# Image file name : 3691630_0
# Product id      : 3691630
# ---------------------------------
# Annoy index     : 79
# Image file name : 3693318_0
# Product id      : 3693318
# ---------------------------------
# Annoy index     : 80
# Image file name : 3696894_0
# Product id      : 3696894
# ---------------------------------
# Annoy index     : 81
# Image file name : 3696894_1
# Product id      : 3696894
# ---------------------------------
# Annoy index     : 82
# Image file name : 3698270_0
# Product id      : 3698270
# ---------------------------------
# Annoy index     : 83
# Image file name : 3699057_0
# Product id      : 3699057
# ---------------------------------
# Annoy index     : 84
# Image file name : 3701704_0
# Product id      : 3701704
# ---------------------------------
# Annoy index     : 85
# Image file name : 3702714_0
# Product id      : 3702714
# ---------------------------------
# Annoy index     : 86
# Image file name : 3707141_0
# Product id      : 3707141
# ---------------------------------
# Annoy index     : 87
# Image file name : 3708836_0
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 88
# Image file name : 3708836_1
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 89
# Image file name : 3708836_2
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 90
# Image file name : 3710299_0
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 91
# Image file name : 3710299_1
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 92
# Image file name : 3710299_2
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 93
# Image file name : 3710465_0
# Product id      : 3710465
# ---------------------------------
# Annoy index     : 94
# Image file name : 3710680_0
# Product id      : 3710680
# ---------------------------------
# Annoy index     : 95
# Image file name : 3713166_0
# Product id      : 3713166
# ---------------------------------
# Annoy index     : 96
# Image file name : 3713230_0
# Product id      : 3713230
# ---------------------------------
# Annoy index     : 97
# Image file name : 3716308_0
# Product id      : 3716308
# ---------------------------------
# Annoy index     : 98
# Image file name : 3718053_0
# Product id      : 3718053
# ---------------------------------
# Annoy index     : 99
# Image file name : 3723050_0
# Product id      : 3723050
# ---------------------------------
# Annoy index     : 100
# Image file name : 3733452_0
# Product id      : 3733452
# ---------------------------------
# Annoy index     : 101
# Image file name : 3735755_0
# Product id      : 3735755
# ---------------------------------
# Annoy index     : 102
# Image file name : 3748219_0
# Product id      : 3748219
# ---------------------------------
# Annoy index     : 103
# Image file name : 3748219_3
# Product id      : 3748219
# ---------------------------------
# Annoy index     : 104
# Image file name : 3767223_0
# Product id      : 3767223
# ---------------------------------
# Annoy index     : 105
# Image file name : 3767223_1
# Product id      : 3767223
# ---------------------------------
# Annoy index     : 106
# Image file name : 3775049_0
# Product id      : 3775049
# ---------------------------------
# Annoy index     : 107
# Image file name : 3775049_1
# Product id      : 3775049
# ---------------------------------
# Annoy index     : 108
# Image file name : 3778102_0
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 109
# Image file name : 3778102_1
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 110
# Image file name : 3778102_2
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 111
# Image file name : 3780937_3
# Product id      : 3780937
# ---------------------------------
# Annoy index     : 112
# Image file name : 3785598_0
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 113
# Image file name : 3785598_1
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 114
# Image file name : 3785598_2
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 115
# Image file name : 3785598_3
# Product id      : 3785598
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started

# %%
#named_nearest_neighbors=[]
cluster()
print("Printing named_nearest_neighbors")
print(named_nearest_neighbors)
print(type(named_nearest_neighbors))
# Out:
# -------Annoy Index Generation----------------
# ---------------------------------
# Annoy index     : 0
# Image file name : 3592260_0
# Product id      : 3592260
# ---------------------------------
# Annoy index     : 1
# Image file name : 3600246_0
# Product id      : 3600246
# ---------------------------------
# Annoy index     : 2
# Image file name : 3606787_1
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 3
# Image file name : 3606787_2
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 4
# Image file name : 3606787_3
# Product id      : 3606787
# ---------------------------------
# Annoy index     : 5
# Image file name : 3607594_0
# Product id      : 3607594
# ---------------------------------
# Annoy index     : 6
# Image file name : 3607977_0
# Product id      : 3607977
# ---------------------------------
# Annoy index     : 7
# Image file name : 3607977_1
# Product id      : 3607977
# ---------------------------------
# Annoy index     : 8
# Image file name : 3615116_0
# Product id      : 3615116
# ---------------------------------
# Annoy index     : 9
# Image file name : 3615116_1
# Product id      : 3615116
# ---------------------------------
# Annoy index     : 10
# Image file name : 3616121_0
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 11
# Image file name : 3616121_1
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 12
# Image file name : 3616121_2
# Product id      : 3616121
# ---------------------------------
# Annoy index     : 13
# Image file name : 3616434_0
# Product id      : 3616434
# ---------------------------------
# Annoy index     : 14
# Image file name : 3616746_0
# Product id      : 3616746
# ---------------------------------
# Annoy index     : 15
# Image file name : 3626900_0
# Product id      : 3626900
# ---------------------------------
# Annoy index     : 16
# Image file name : 3627022_0
# Product id      : 3627022
# ---------------------------------
# Annoy index     : 17
# Image file name : 3627022_1
# Product id      : 3627022
# ---------------------------------
# Annoy index     : 18
# Image file name : 3627537_0
# Product id      : 3627537
# ---------------------------------
# Annoy index     : 19
# Image file name : 3632446_0
# Product id      : 3632446
# ---------------------------------
# Annoy index     : 20
# Image file name : 3638804_0
# Product id      : 3638804
# ---------------------------------
# Annoy index     : 21
# Image file name : 3641703_0
# Product id      : 3641703
# ---------------------------------
# Annoy index     : 22
# Image file name : 3641703_1
# Product id      : 3641703
# ---------------------------------
# Annoy index     : 23
# Image file name : 3644655_0
# Product id      : 3644655
# ---------------------------------
# Annoy index     : 24
# Image file name : 3650251_0
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 25
# Image file name : 3650251_1
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 26
# Image file name : 3650251_2
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 27
# Image file name : 3650251_3
# Product id      : 3650251
# ---------------------------------
# Annoy index     : 28
# Image file name : 3650946_0
# Product id      : 3650946
# ---------------------------------
# Annoy index     : 29
# Image file name : 3651269_0
# Product id      : 3651269
# ---------------------------------
# Annoy index     : 30
# Image file name : 3652195_0
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 31
# Image file name : 3652195_1
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 32
# Image file name : 3652195_2
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 33
# Image file name : 3652195_3
# Product id      : 3652195
# ---------------------------------
# Annoy index     : 34
# Image file name : 3657088_0
# Product id      : 3657088
# ---------------------------------
# Annoy index     : 35
# Image file name : 3657088_1
# Product id      : 3657088
# ---------------------------------
# Annoy index     : 36
# Image file name : 3657693_0
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 37
# Image file name : 3657693_1
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 38
# Image file name : 3657693_2
# Product id      : 3657693
# ---------------------------------
# Annoy index     : 39
# Image file name : 3658475_0
# Product id      : 3658475
# ---------------------------------
# Annoy index     : 40
# Image file name : 3659954_0
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 41
# Image file name : 3659954_1
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 42
# Image file name : 3659954_2
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 43
# Image file name : 3659954_3
# Product id      : 3659954
# ---------------------------------
# Annoy index     : 44
# Image file name : 3661414_0
# Product id      : 3661414
# ---------------------------------
# Annoy index     : 45
# Image file name : 3661414_1
# Product id      : 3661414
# ---------------------------------
# Annoy index     : 46
# Image file name : 3669338_0
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 47
# Image file name : 3669338_1
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 48
# Image file name : 3669338_2
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 49
# Image file name : 3669338_3
# Product id      : 3669338
# ---------------------------------
# Annoy index     : 50
# Image file name : 3672632_0
# Product id      : 3672632
# ---------------------------------
# Annoy index     : 51
# Image file name : 3673600_0
# Product id      : 3673600
# ---------------------------------
# Annoy index     : 52
# Image file name : 3673600_1
# Product id      : 3673600
# ---------------------------------
# Annoy index     : 53
# Image file name : 3673616_0
# Product id      : 3673616
# ---------------------------------
# Annoy index     : 54
# Image file name : 3674036_0
# Product id      : 3674036
# ---------------------------------
# Annoy index     : 55
# Image file name : 3676447_0
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 56
# Image file name : 3676447_1
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 57
# Image file name : 3676447_2
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 58
# Image file name : 3676447_3
# Product id      : 3676447
# ---------------------------------
# Annoy index     : 59
# Image file name : 3678695_0
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 60
# Image file name : 3678695_1
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 61
# Image file name : 3678695_2
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 62
# Image file name : 3678695_3
# Product id      : 3678695
# ---------------------------------
# Annoy index     : 63
# Image file name : 3681709_0
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 64
# Image file name : 3681709_1
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 65
# Image file name : 3681709_2
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 66
# Image file name : 3681709_3
# Product id      : 3681709
# ---------------------------------
# Annoy index     : 67
# Image file name : 3683369_0
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 68
# Image file name : 3683369_1
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 69
# Image file name : 3683369_2
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 70
# Image file name : 3683369_3
# Product id      : 3683369
# ---------------------------------
# Annoy index     : 71
# Image file name : 3683720_0
# Product id      : 3683720
# ---------------------------------
# Annoy index     : 72
# Image file name : 3683720_1
# Product id      : 3683720
# ---------------------------------
# Annoy index     : 73
# Image file name : 3689141_0
# Product id      : 3689141
# ---------------------------------
# Annoy index     : 74
# Image file name : 3689141_1
# Product id      : 3689141
# ---------------------------------
# Annoy index     : 75
# Image file name : 3689266_0
# Product id      : 3689266
# ---------------------------------
# Annoy index     : 76
# Image file name : 3690110_0
# Product id      : 3690110
# ---------------------------------
# Annoy index     : 77
# Image file name : 3691506_0
# Product id      : 3691506
# ---------------------------------
# Annoy index     : 78
# Image file name : 3691630_0
# Product id      : 3691630
# ---------------------------------
# Annoy index     : 79
# Image file name : 3693318_0
# Product id      : 3693318
# ---------------------------------
# Annoy index     : 80
# Image file name : 3696894_0
# Product id      : 3696894
# ---------------------------------
# Annoy index     : 81
# Image file name : 3696894_1
# Product id      : 3696894
# ---------------------------------
# Annoy index     : 82
# Image file name : 3698270_0
# Product id      : 3698270
# ---------------------------------
# Annoy index     : 83
# Image file name : 3699057_0
# Product id      : 3699057
# ---------------------------------
# Annoy index     : 84
# Image file name : 3701704_0
# Product id      : 3701704
# ---------------------------------
# Annoy index     : 85
# Image file name : 3702714_0
# Product id      : 3702714
# ---------------------------------
# Annoy index     : 86
# Image file name : 3707141_0
# Product id      : 3707141
# ---------------------------------
# Annoy index     : 87
# Image file name : 3708836_0
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 88
# Image file name : 3708836_1
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 89
# Image file name : 3708836_2
# Product id      : 3708836
# ---------------------------------
# Annoy index     : 90
# Image file name : 3710299_0
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 91
# Image file name : 3710299_1
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 92
# Image file name : 3710299_2
# Product id      : 3710299
# ---------------------------------
# Annoy index     : 93
# Image file name : 3710465_0
# Product id      : 3710465
# ---------------------------------
# Annoy index     : 94
# Image file name : 3710680_0
# Product id      : 3710680
# ---------------------------------
# Annoy index     : 95
# Image file name : 3713166_0
# Product id      : 3713166
# ---------------------------------
# Annoy index     : 96
# Image file name : 3713230_0
# Product id      : 3713230
# ---------------------------------
# Annoy index     : 97
# Image file name : 3716308_0
# Product id      : 3716308
# ---------------------------------
# Annoy index     : 98
# Image file name : 3718053_0
# Product id      : 3718053
# ---------------------------------
# Annoy index     : 99
# Image file name : 3723050_0
# Product id      : 3723050
# ---------------------------------
# Annoy index     : 100
# Image file name : 3733452_0
# Product id      : 3733452
# ---------------------------------
# Annoy index     : 101
# Image file name : 3735755_0
# Product id      : 3735755
# ---------------------------------
# Annoy index     : 102
# Image file name : 3748219_0
# Product id      : 3748219
# ---------------------------------
# Annoy index     : 103
# Image file name : 3748219_3
# Product id      : 3748219
# ---------------------------------
# Annoy index     : 104
# Image file name : 3767223_0
# Product id      : 3767223
# ---------------------------------
# Annoy index     : 105
# Image file name : 3767223_1
# Product id      : 3767223
# ---------------------------------
# Annoy index     : 106
# Image file name : 3775049_0
# Product id      : 3775049
# ---------------------------------
# Annoy index     : 107
# Image file name : 3775049_1
# Product id      : 3775049
# ---------------------------------
# Annoy index     : 108
# Image file name : 3778102_0
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 109
# Image file name : 3778102_1
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 110
# Image file name : 3778102_2
# Product id      : 3778102
# ---------------------------------
# Annoy index     : 111
# Image file name : 3780937_3
# Product id      : 3780937
# ---------------------------------
# Annoy index     : 112
# Image file name : 3785598_0
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 113
# Image file name : 3785598_1
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 114
# Image file name : 3785598_2
# Product id      : 3785598
# ---------------------------------
# Annoy index     : 115
# Image file name : 3785598_3
# Product id      : 3785598
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# Printing named_nearest_neighbors
# [{'similarity': 1.0, 'master_pi': '3592260', 'similar_pi': '3592260'}, {'similarity': 0.7826, 'master_pi': '3592260', 'similar_pi': '3607977'}, {'similarity': 0.7724, 'master_pi': '3592260', 'similar_pi': '3652195'}, {'similarity': 0.7577, 'master_pi': '3592260', 'similar_pi': '3674036'}, {'similarity': 0.7556, 'master_pi': '3592260', 'similar_pi': '3652195'}, {'similarity': 0.7531, 'master_pi': '3592260', 'similar_pi': '3678695'}, {'similarity': 0.7525, 'master_pi': '3592260', 'similar_pi': '3710680'}, {'similarity': 0.7493, 'master_pi': '3592260', 'similar_pi': '3641703'}, {'similarity': 0.7471, 'master_pi': '3592260', 'similar_pi': '3659954'}, {'similarity': 0.744, 'master_pi': '3592260', 'similar_pi': '3669338'}, {'similarity': 0.7423, 'master_pi': '3592260', 'similar_pi': '3678695'}, {'similarity': 0.7409, 'master_pi': '3592260', 'similar_pi': '3650251'}, {'similarity': 0.7357, 'master_pi': '3592260', 'similar_pi': '3615116'}, {'similarity': 0.7357, 'master_pi': '3592260', 'similar_pi': '3615116'}, {'similarity': 0.7329, 'master_pi': '3592260', 'similar_pi': '3652195'}, {'similarity': 0.7317, 'master_pi': '3592260', 'similar_pi': '3775049'}, {'similarity': 0.7268, 'master_pi': '3592260', 'similar_pi': '3650251'}, {'similarity': 0.7241, 'master_pi': '3592260', 'similar_pi': '3690110'}, {'similarity': 0.7236, 'master_pi': '3592260', 'similar_pi': '3710299'}, {'similarity': 0.7206, 'master_pi': '3592260', 'similar_pi': '3607977'}, {'similarity': 1.0, 'master_pi': '3600246', 'similar_pi': '3600246'}, {'similarity': 0.7618, 'master_pi': '3600246', 'similar_pi': '3676447'}, {'similarity': 0.7314, 'master_pi': '3600246', 'similar_pi': '3673600'}, {'similarity': 0.7291, 'master_pi': '3600246', 'similar_pi': '3691630'}, {'similarity': 0.7266, 'master_pi': '3600246', 'similar_pi': '3676447'}, {'similarity': 0.7237, 'master_pi': '3600246', 'similar_pi': '3681709'}, {'similarity': 0.7223, 'master_pi': '3600246', 'similar_pi': '3767223'}, {'similarity': 0.7223, 'master_pi': '3600246', 'similar_pi': '3696894'}, {'similarity': 0.7211, 'master_pi': '3600246', 'similar_pi': '3735755'}, {'similarity': 0.7113, 'master_pi': '3600246', 'similar_pi': '3716308'}, {'similarity': 0.7103, 'master_pi': '3600246', 'similar_pi': '3748219'}, {'similarity': 0.7071, 'master_pi': '3600246', 'similar_pi': '3616121'}, {'similarity': 0.7068, 'master_pi': '3600246', 'similar_pi': '3678695'}, {'similarity': 0.7067, 'master_pi': '3600246', 'similar_pi': '3699057'}, {'similarity': 0.7051, 'master_pi': '3600246', 'similar_pi': '3673600'}, {'similarity': 0.7018, 'master_pi': '3600246', 'similar_pi': '3650251'}, {'similarity': 0.7006, 'master_pi': '3600246', 'similar_pi': '3775049'}, {'similarity': 0.6997, 'master_pi': '3600246', 'similar_pi': '3778102'}, {'similarity': 0.6988, 'master_pi': '3600246', 'similar_pi': '3638804'}, {'similarity': 0.697, 'master_pi': '3600246', 'similar_pi': '3683369'}, {'similarity': 1.0, 'master_pi': '3606787', 'similar_pi': '3606787'}, {'similarity': 0.8863, 'master_pi': '3606787', 'similar_pi': '3606787'}, {'similarity': 0.8802, 'master_pi': '3606787', 'similar_pi': '3606787'}, {'similarity': 0.6972, 'master_pi': '3606787', 'similar_pi': '3652195'}, {'similarity': 0.6856, 'master_pi': '3606787', 'similar_pi': '3669338'}, {'similarity': 0.6072, 'master_pi': '3606787', 'similar_pi': '3659954'}, {'similarity': 0.5882, 'master_pi': '3606787', 'similar_pi': '3657088'}, {'similarity': 0.5817, 'master_pi': '3606787', 'similar_pi': '3658475'}, {'similarity': 0.581, 'master_pi': '3606787', 'similar_pi': '3785598'}, {'similarity': 0.5782, 'master_pi': '3606787', 'similar_pi': '3681709'}, {'similarity': 0.5651, 'master_pi': '3606787', 'similar_pi': '3669338'}, {'similarity': 0.5587, 'master_pi': '3606787', 'similar_pi': '3657693'}, {'similarity': 0.5537, 'master_pi': '3606787', 'similar_pi': '3659954'}, {'similarity': 0.5514, 'master_pi': '3606787', 'similar_pi': '3780937'}, {'similarity': 0.5466, 'master_pi': '3606787', 'similar_pi': '3683369 ...
# <class 'list'>

# %%
from scipy import spatial
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
def search_similar_image(reference_image, max_results):
    plt.imshow(mpimg.imread('images/'+reference_image))
    reference_image = '_'.join(reference_image.split('_')[:-1])
    print(reference_image)
    nearest = []
    for i in range (0, len(named_nearest_neighbors)):
        if(named_nearest_neighbors[i]['master_pi'] == reference_image):
            nearest.append({
                'similarity' : named_nearest_neighbors[i]['similarity'],
                'master_pi' : named_nearest_neighbors[i]['master_pi'],
                'similar_pi' : named_nearest_neighbors[i]['similar_pi']
            })
    
    f, ax = plt.subplots(1, max_results, figsize=(16, 8))
    for i in range(0, max_results):
        for j in range(0, len(images)):
            if(nearest[i]['similar_pi'] == images[j]['product_id']):
                ax[i].imshow(images[j]['image'])
                ax[i].set_axis_off()                
    plt.show()

# %%
search_similar_image('3748219_0.jpg',10)
# Out:
# 3748219

# %%
search_similar_image('3627022_0.jpg',10)
# Out:
# 3627022

# %%
search_similar_image('3641703_1.jpg',10)
# Out:
# 3641703
